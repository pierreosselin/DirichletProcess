# %%
from ObjectDP import *

# %%
data1 = np.random.multivariate_normal([0,0], 0.01*np.eye(2), 40)
data2 = np.random.multivariate_normal([0,1], 0.01*np.eye(2), 40)
data3 = np.random.multivariate_normal([1,0], 0.01*np.eye(2), 40)
#data4 = np.random.multivariate_normal([1,0,0], 0.01*np.eye(3), 40)

data = np.concatenate((np.concatenate((data1, data2)), data3))
#data = np.concatenate((data, data4))

# %%
diri = DirichletMixtureConjugate(data, K_ini = 1)

# %%
diri.fit(epoch = 10, vis = True)

# %%
diri.parameters
# Out:
# [[array([ 1.31857589, -0.65802862]), array([[ 0.7072259 , -0.32738455],
#          [-0.32738455,  0.21496984]])],
#  [array([-0.54681738, -0.52808931]), array([[0.15853394, 0.10883007],
#          [0.10883007, 0.15927173]])],
#  [array([-0.65847701,  1.33190532]), array([[ 0.16983375, -0.25903539],
#          [-0.25903539,  0.59597812]])]]

# %%
diri.plot()

# %%
plt.plot(diri.history["logLikelihood"])

# %%
diri.labels

# %%
diri.parameters

# %%
plt.hist(diri.history["nbClusters"],bins = 100)
